# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = ["Far far away, behind the word mountains, far from the countries Vokalia and Consonantia, there live the blind texts. ",
"Separated they live in Bookmarksgrove right at the coast of the Semantics, a large language ocean. ",
"A small river named Duden flows by their place and supplies it with the necessary regelialia. ", 
"It is a paradisematic country, in which roasted parts of sentences fly into your mouth."]

# %% [markdown]
# Create TF-IDF vectorizer

# %%
vectorizer = TfidfVectorizer(stop_words='english')

# %% [markdown]
# Fit and transform the documents

# %%
tfidf_matrix = vectorizer.fit_transform(documents)

# %% [markdown]
# Get feature names

# %%
feature_names = vectorizer.get_feature_names_out()
print(feature_names)
# Out:
# ['away' 'blind' 'bookmarksgrove' 'coast' 'consonantia' 'countries'
#  'country' 'duden' 'far' 'flows' 'fly' 'language' 'large' 'live'
#  'mountains' 'mouth' 'named' 'necessary' 'ocean' 'paradisematic' 'parts'
#  'place' 'regelialia' 'right' 'river' 'roasted' 'semantics' 'sentences'
#  'separated' 'small' 'supplies' 'texts' 'vokalia' 'word']

# %% [markdown]
# Display TF-IDF scores

# %%
for doc_idx, doc in enumerate(documents):
    print(f"\n Top keywords in document{doc_idx +1}:")
    scores = tfidf_matrix[doc_idx].toarray()[0]
    top_incides = scores.argsort()[-5:][::-1]
    for idx in top_incides:
        print(f"{feature_names[idx]}:{scores[idx]:.4f}")
# Out:
#  Top keywords in document1:
# far:0.7147
# word:0.2382
# vokalia:0.2382
# texts:0.2382
# blind:0.2382
#
#  Top keywords in document2:
# semantics:0.3406
# separated:0.3406
# bookmarksgrove:0.3406
# coast:0.3406
# ocean:0.3406
#
#  Top keywords in document3:
# small:0.3333
# supplies:0.3333
# duden:0.3333
# necessary:0.3333
# river:0.3333
#
#  Top keywords in document4:
# sentences:0.3780
# roasted:0.3780
# fly:0.3780
# country:0.3780
# paradisematic:0.3780
